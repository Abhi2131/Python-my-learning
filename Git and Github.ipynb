# %% [markdown]
# ### Git and Github 🎁

# %% [markdown]
#     * to install git : https://git-scm.com/downloads
#     *  we neeed to creat a account on it ( i craeted with Username : ABhi2131, PW: Abhi@2131)

# %% [markdown]
# ### GIT:
#     * it is simply a Version Control System(VCS) that means cloud based sustem in which collborately we could write code with great flexibilty.
#         - best way to have a track to check changes made in file
#         - how changes made by different people on same file that too we can  track uing git
#         - used to track different versions of same apllication
#         - to track history
#         - track changes over time
#         - ability to have unlimited number of developers working on the  same code base
#         - Easily revert back your files if something happened

# %% [markdown]
# Version control system have two main types:
#         1. Centralised Version Control System (CVCS)
#         2. Distributed Version Control System  (DVCS)
#
# 1. CVCS:![cscv.png](attachment:cscv.png)
#     - all local systems are connected directly with the central system eg.clearcse and subversion
#       Disadv:
#      - 1.if CVSC downs/loss files, all local system has to wait till central CVCS correct itself.
#      - 2.no backup server if goes down or it crashes
#      - 3.slower as compared to DVCS
#
# -2. DVCS:![dvcs.png](attachment:dvcs.png)
#     - central system as well as all ocal systems are internally connected eg.Git and Github
#       adv:
#      - 1.any change made by one person is available for everyone connected in system
#      - 2.overcomes all disadv of CVCS
#      - 3.can backup code easily if server crashes or goes down

# %% [markdown]
# ### differance between git and github
#
# ![unnamed.jpg](attachment:unnamed.jpg)

# %% [markdown]
# ### - Repository??
#    - 'repos' = repository ,in simple word it is hosting a project
#    - Usually used to organize a single project
#    - Repos can contain folders and files, images, videos, spreadsheet, and datasets – anything your project needs

# %% [markdown]
# ### Basic linux commands:
#    - pwd (present working directory): used to check the current directory you are working on
#    - ls: list all the files and folders in the current directory
#    - ls -al: list all the files and folders in the current directory including hidden files
#    - cd (change directory): to the change the directory
#    - mkdir (make directory): to make a new directory
#        - syntax – mkdir ‘directory name’
#    - mv (move): to move the directory from one folder to another
#        - syntax – mv ‘src directory name’ ‘dest directory name’
#    - rmdir (remove directory name) -  to remove a particular library
#        - syntax – rmdir ‘Dir name’
#    - vim: powerfull text editor used in CLI (command line interface)
#        - syntax – vim <filename>
#    - cat – open a file in CLI(command line interface)
#        - syntax – cat <filename>

# %% [markdown]
# ### git architecture:
# ![hhh.png](attachment:hhh.png)

# %% [markdown]
# ### Start using Git bash software at your local system:
#    1. Configure your users
#      - git config --global user.name “<_name_>”
#      - git config --global user.email “<_email addr_>”
#    2. check the configuration (to view ^ this)
#      - git config --global --list
#    3. setting core.autocrlf
#       - for window users
#               - git config --global core.autocrlf true

# %% [markdown]
# ### creating repo on github
#    1. Sign in into your GitHub Account
#    2.Click in the new repository to create a new repository
#    ![l.png](attachment:l.png)
#    3. give the repository name
#    ![hhh.png](attachment:hhh.png)
#    4. give the description if required
#    ![k.png](attachment:k.png)
#    5.Select the visibility of the repo to world
#    ![kk.png](attachment:kk.png)
#    6.Assign ro the readme.md
#    ![kkk.png](attachment:kkk.png)
#    7.Click on the create button to create the repo

# %% [markdown]
# ### cloning the repo:
#   1. Click on the code button an copy the link under https
#   ![hi.png](attachment:hi.png)
#   2. Create a folder in directory of your choice
#   3. write the below command to clone the repo
#           - git clone < link of the repo>

# %% [markdown]
#  4. Create four folder inside a cloned repo
#           - Python
#           - Stats
#           - machine learning
#           - Assignmnet
#     - { here as i want to clone everything from my dekstop folder named 'git repo', i will first check current directory using pwd, the list all files using ls,then change directory to to git repo using cd.}

# %% [markdown]
#  5. create a python file inside a folder
#       - file1.py
#       - file2.py
#       -  while writing code use cat - to show content, wq to save file
#       - vim f1.py - an editor to write code
#                   - then type 'i' to write or insert a code
#                   {vim is simply open existed file if present or it will create a file
#       - after writing code press esc button
#       then to save type ' : wq'

# %% [markdown]
#   6. check the status of the file
#       - git status
#   7. add the untracked file to that staging area
#       - git add <filename>
#       - git add <filename> <filename>
#       - git add .
#   8. Commit the files to put into the local repo
#       - syntax – git commit -m ‘<message>’
#   9. Push the files in the cloud repo
#       - syntax – git push origin master
#   10. Pull the files form the cloud repo
#       - syntax – git pull origin master
